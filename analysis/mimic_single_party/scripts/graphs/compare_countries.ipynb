# %%
import matplotlib.pyplot as plt
import json 
import matplotlib.cm as cm
import numpy as np

# %%
methods = ['plurality', 'borda-om', 'approval', 'top-3-truncation', 'top-two', 'bucklin', 'IRV', 'borda-avg', 'borda-pm', 'condorcet', 'smith', 'smith_plurality', 'minimax', 'ranked-pairs', 'smith_irv', 'smith-minimax']
#methods = ['plurality', 'borda-om', 'approval', 'top-3-truncation', 'top-two', 'bucklin', 'IRV', 'borda-avg', 'borda-pm', 'condorcet', 'smith_plurality', 'minimax', 'ranked-pairs', 'smith_irv', 'smith-minimax']

# %%
## stability files
with open('/Users/karenxiao/MyPythonCode/ranked_choice_voting/rcv_proposal/analysis/mimic_single_party/methods/borda_score/stability/scotland_results_top4.json') as file:
    borda_score_stability = json.load(file)

with open('/Users/karenxiao/MyPythonCode/ranked_choice_voting/rcv_proposal/analysis/mimic_single_party/methods/mention_score/stability/scotland_results_top4.json') as file:
    mention_score_stability = json.load(file)

with open('/Users/karenxiao/MyPythonCode/ranked_choice_voting/rcv_proposal/analysis/mimic_single_party/methods/first_place_score/stability/scotland_results_top4.json') as file:
    first_place_score_stability = json.load(file)

with open('/Users/karenxiao/MyPythonCode/ranked_choice_voting/rcv_proposal/analysis/mimic_single_party/methods/first_last_mentioned/keep_first/scotland_results_top4.json') as file:
    keep_first_stability = json.load(file)

with open('/Users/karenxiao/MyPythonCode/ranked_choice_voting/rcv_proposal/analysis/mimic_single_party/methods/first_last_mentioned/keep_last/scotland_results_top4.json') as file:
    keep_last_stability = json.load(file)

with open('/Users/karenxiao/MyPythonCode/ranked_choice_voting/rcv_proposal/analysis/mimic_single_party/methods/tiebreaker/borda/scotland_results_top4.json') as file:
    borda_tiebreaker_stability = json.load(file)

with open('/Users/karenxiao/MyPythonCode/ranked_choice_voting/rcv_proposal/analysis/mimic_single_party/methods/tiebreaker/mention/scotland_results_top4.json') as file:
    mention_tiebreaker_stability = json.load(file)

with open('/Users/karenxiao/MyPythonCode/ranked_choice_voting/rcv_proposal/analysis/mimic_single_party/methods/tiebreaker/first_place/scotland_results_top4.json') as file:
    first_place_tiebreaker_stability = json.load(file)

borda_data_stability = borda_score_stability["metadata"]["method_counts"]
first_place_data_stability = first_place_score_stability["metadata"]["method_counts"]
mention_data_stability = mention_score_stability["metadata"]["method_counts"]
keep_first_stability = keep_first_stability["metadata"]["method_counts"]
keep_last_stability = keep_last_stability["metadata"]["method_counts"]
borda_tiebreaker_data_stability = borda_tiebreaker_stability["metadata"]["method_counts"]
first_place_tiebreaker_data_stability = first_place_tiebreaker_stability["metadata"]["method_counts"]
mention_tiebreaker_data_stability = mention_tiebreaker_stability["metadata"]["method_counts"]

borda_data_stability = {key: borda_data_stability[key] for key in methods if key in borda_data_stability}
first_place_data_stability = {key: first_place_data_stability[key] for key in methods if key in first_place_data_stability} 
mention_data_stability = {key: mention_data_stability[key] for key in methods if key in mention_data_stability}
keep_first_data_stability = {key: keep_first_stability[key] for key in methods if key in keep_first_stability} 
keep_last_data_stability = {key: keep_last_stability[key] for key in methods if key in keep_last_stability}
borda_tiebreaker_data_stability = {key: borda_tiebreaker_data_stability[key] for key in methods if key in borda_tiebreaker_data_stability}
first_place_tiebreaker_data_stability = {key: first_place_tiebreaker_data_stability[key] for key in methods if key in first_place_tiebreaker_data_stability} 
mention_tiebreaker_data_stability = {key: mention_tiebreaker_data_stability[key] for key in methods if key in mention_tiebreaker_data_stability}

# %%
## spoiler files
with open('/Users/karenxiao/MyPythonCode/ranked_choice_voting/rcv_proposal/analysis/mimic_single_party/methods/borda_score/spoiler/winners_with_metadata.json') as file:
    borda_score_spoiler = json.load(file)

with open('/Users/karenxiao/MyPythonCode/ranked_choice_voting/rcv_proposal/analysis/mimic_single_party/methods/mention_score/spoiler/winners_with_metadata.json') as file:
    mention_score_spoiler = json.load(file)

with open('/Users/karenxiao/MyPythonCode/ranked_choice_voting/rcv_proposal/analysis/mimic_single_party/methods/first_place_score/spoiler/winners_with_metadata.json') as file:
    first_place_score_spoiler = json.load(file)

with open('/Users/karenxiao/MyPythonCode/ranked_choice_voting/rcv_proposal/analysis/mimic_single_party/methods/first_last_mentioned/keep_first/spoiler/winners_with_metadata.json') as file:
    keep_first_spoiler = json.load(file)

with open('/Users/karenxiao/MyPythonCode/ranked_choice_voting/rcv_proposal/analysis/mimic_single_party/methods/first_last_mentioned/keep_last/spoiler/winners_with_metadata.json') as file:
    keep_last_spoiler = json.load(file)

with open('/Users/karenxiao/MyPythonCode/ranked_choice_voting/rcv_proposal/analysis/mimic_single_party/methods/tiebreaker/borda/spoiler/winners_with_metadata.json') as file:
    borda_tiebreaker_spoiler = json.load(file)

with open('/Users/karenxiao/MyPythonCode/ranked_choice_voting/rcv_proposal/analysis/mimic_single_party/methods/tiebreaker/mention/spoiler/winners_with_metadata.json') as file:
    mention_tiebreaker_spoiler = json.load(file)

with open('/Users/karenxiao/MyPythonCode/ranked_choice_voting/rcv_proposal/analysis/mimic_single_party/methods/tiebreaker/first_place/spoiler/winners_with_metadata.json') as file:
    first_place_tiebreaker_spoiler = json.load(file)

borda_data_spoiler = borda_score_spoiler["metadata"]["method_counts"]
first_place_data_spoiler = first_place_score_spoiler["metadata"]["method_counts"]
mention_data_spoiler = mention_score_spoiler["metadata"]["method_counts"]
keep_first_spoiler = keep_first_spoiler["metadata"]["method_counts"]
keep_last_spoiler = keep_last_spoiler["metadata"]["method_counts"]
borda_tiebreaker_data_spoiler = borda_tiebreaker_spoiler["metadata"]["method_counts"]
first_place_tiebreaker_data_spoiler = first_place_tiebreaker_spoiler["metadata"]["method_counts"]
mention_tiebreaker_data_spoiler = mention_tiebreaker_spoiler["metadata"]["method_counts"]

borda_data_spoiler = {key: borda_data_spoiler[key] for key in methods if key in borda_data_spoiler}
first_place_data_spoiler = {key: first_place_data_spoiler[key] for key in methods if key in first_place_data_spoiler} 
mention_data_spoiler = {key: mention_data_spoiler[key] for key in methods if key in mention_data_spoiler}
keep_first_data_spoiler = {key: keep_first_spoiler[key] for key in methods if key in keep_first_spoiler} 
keep_last_data_spoiler = {key: keep_last_spoiler[key] for key in methods if key in keep_last_spoiler}
borda_tiebreaker_data_spoiler = {key: borda_tiebreaker_data_spoiler[key] for key in methods if key in borda_tiebreaker_data_spoiler}
first_place_tiebreaker_data_spoiler = {key: first_place_tiebreaker_data_spoiler[key] for key in methods if key in first_place_tiebreaker_data_spoiler} 
mention_tiebreaker_data_spoiler = {key: mention_tiebreaker_data_spoiler[key] for key in methods if key in mention_tiebreaker_data_spoiler}

# %%
## original files
with open('/Users/karenxiao/MyPythonCode/ranked_choice_voting/rcv_proposal/analysis/stability/results/scotland_results_top4.json') as file:
    scotland_original_stability = json.load(file)

with open('/Users/karenxiao/MyPythonCode/ranked_choice_voting/rcv_proposal/analysis/stability/results/america_results_top4.json') as file:
    america_original_stability = json.load(file)

with open('//Users/karenxiao/MyPythonCode/ranked_choice_voting/rcv_proposal/analysis/stability/results/australia_results_top4.json') as file:
    australia_original_stability = json.load(file)

with open('/Users/karenxiao/MyPythonCode/ranked_choice_voting/rcv_proposal/analysis/spoiler/scotland.json') as file:
    scotland_original_spoiler = json.load(file)

with open('/Users/karenxiao/MyPythonCode/ranked_choice_voting/rcv_proposal/analysis/spoiler/america.json') as file:
    america_original_spoiler = json.load(file)

with open('/Users/karenxiao/MyPythonCode/ranked_choice_voting/rcv_proposal/analysis/spoiler/australia.json') as file:
    australia_original_spoiler = json.load(file)

scotland_original_data_stability = scotland_original_stability["metadata"]["method_counts"]
scotland_original_data_stability = {key: scotland_original_data_stability[key] for key in methods if key in scotland_original_data_stability}
america_original_data_stability = america_original_stability["metadata"]["method_counts"]
america_original_data_stability = {key: america_original_data_stability[key] for key in methods if key in america_original_data_stability}
australia_original_data_stability = australia_original_stability["metadata"]["method_counts"]
australia_original_data_stability = {key: australia_original_data_stability[key] for key in methods if key in australia_original_data_stability}

scotland_original_data_spoiler = scotland_original_spoiler["metadata"]["method_counts"]
scotland_original_data_spoiler = {key: scotland_original_data_spoiler[key] for key in methods if key in scotland_original_data_spoiler}
america_original_data_spoiler = america_original_spoiler["metadata"]["method_counts"]
america_original_data_spoiler = {key: america_original_data_spoiler[key] for key in methods if key in america_original_data_spoiler}
australia_original_data_spoiler = australia_original_spoiler["metadata"]["method_counts"]

for m in methods:
    if m not in australia_original_data_spoiler:
        australia_original_data_spoiler[m] = 0
australia_original_data_spoiler = {key: australia_original_data_spoiler[key] for key in methods if key in australia_original_data_spoiler}

# %%
def create_stability_graph(ax, data, title):
    n = len(methods)
    r = np.arange(n) 
    width = 0.2

    ax.bar(r + 0*width, list(scotland_original_data_stability.values()), color="midnightblue", width=width, label='original scotland')
    ax.bar(r + 1*width, list(america_original_data_stability.values()), color="maroon", width=width, label='original america')
    ax.bar(r + 2*width, list(australia_original_data_stability.values()), color="orange", width=width, label='original australia')
    ax.bar(r + 3*width, list(data.values()), color="lightsteelblue", width=width, label='condensed')

    ax.set_xlabel("Method")
    ax.set_ylabel("Count")
    ax.set_xticks(r + width/2)
    ax.set_xticklabels(methods, rotation=40)
    ax.set_title(title)
    ax.legend()

# Create a single figure with two subplots side by side
fig, axs = plt.subplots(4, 2, figsize=(18, 20))  # 1 row, 2 columns

# Plot on each axis
create_stability_graph(axs[0,0], borda_data_stability, "Borda Score Stability")
create_stability_graph(axs[1,0], mention_data_stability, "Mention Score Stability")
create_stability_graph(axs[2,0], first_place_data_stability, "First Place Score Stability")
create_stability_graph(axs[0,1], borda_tiebreaker_data_stability, "Borda Tiebreaker Stability")
create_stability_graph(axs[1,1], mention_tiebreaker_data_stability, "Mention Tiebreaker Stability")
create_stability_graph(axs[2,1], first_place_tiebreaker_data_stability, "First Place Tiebreaker Stability")
create_stability_graph(axs[3,0], keep_first_data_stability, "Keep First Stability")
create_stability_graph(axs[3,1], keep_last_data_stability, "Keep Last Stability")

plt.tight_layout()
plt.show()

# %%
def create_spoiler_graph(ax, data, title):
    n = len(methods)
    r = np.arange(n) 
    width = 0.2
    ax.bar(r + 0*width, list(scotland_original_data_spoiler.values()), color="midnightblue", width=width, label='original scotland')
    ax.bar(r + 1*width, list(america_original_data_spoiler.values()), color="maroon", width=width, label='original america')
    ax.bar(r + 2*width, list(australia_original_data_spoiler.values()), color="orange", width=width, label='original australia')
    ax.bar(r + 3*width, list(data.values()), color="lightsteelblue", width=width, label='condensed')

    ax.set_xlabel("Method")
    ax.set_ylabel("Count")
    ax.set_xticks(r + width/2)
    ax.set_xticklabels(methods, rotation=40)
    ax.set_title(title)
    ax.legend()

# Create a single figure with two subplots side by side
fig, axs = plt.subplots(4, 2, figsize=(18, 20))  # 1 row, 2 columns

# Plot on each axis
create_spoiler_graph(axs[0,0], borda_data_spoiler, "Borda Score Spoiler")
create_spoiler_graph(axs[1,0], mention_data_spoiler, "Mention Score Spoiler")
create_spoiler_graph(axs[2,0], first_place_data_spoiler, "First Place Score Spoiler")
create_spoiler_graph(axs[0,1], borda_tiebreaker_data_spoiler, "Borda Tiebreaker Spoiler")
create_spoiler_graph(axs[1,1], mention_tiebreaker_data_spoiler, "Mention Tiebreaker Spoiler")
create_spoiler_graph(axs[2,1], first_place_tiebreaker_data_spoiler, "First Place Tiebreaker Spoiler")
create_spoiler_graph(axs[3,0], keep_first_data_spoiler, "Keep First Spoiler")
create_spoiler_graph(axs[3,1], keep_last_data_spoiler, "Keep Last Spoiler")

plt.tight_layout()
plt.show()
